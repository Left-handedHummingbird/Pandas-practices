# %%
import pandas as pd
import numpy as np

Tdulces = pd.read_excel("C:\\Users\\Nobody\\Documents\\Python Scripts\\File.xlsx")
filename = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df = pd.read_csv(filename, names = headers)

# %%
Tdulces
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                  Bocadines    Ricolino               50.0
# 3                Gelatinitas    Kellog's               40.0
# 4                 Pulparindo  De la rosa               22.0
# 5                  Skwinkles       Lucas                NaN
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               33.0
# 14               Dragoncitos      Sonrix               15.0
# 15           Paleta de mango        Vero               50.0
#
#     Unidades por paquete      Sabor
# 0                      5      Dulce
# 1                     80      Dulce
# 2                     50      Dulce
# 3                    100      Dulce
# 4                     20  Enchiloso
# 5                     60  Enchiloso
# 6                      6  Enchiloso
# 7                      6  Enchiloso
# 8                     40      Dulce
# 9                    100      Dulce
# 10                   100      Dulce
# 11                    25      Dulce
# 12                    50      Dulce
# 13                    12  Enchiloso
# 14                   100      Dulce
# 15                    50  Enchiloso

# %%
Precios = Tdulces[['Costo del paquete']]

# %%
Estratos = np.linspace(min(Tdulces["Costo del paquete"]),max(Tdulces["Costo del paquete"]),4)

# %%
Cabeceras = ["Bajo","Medio","Alto"]

# %%
Tdulces['Precios Estratificados'] = pd.cut(Tdulces["Costo del paquete"] ,Estratos,labels=Cabeceras, include_lowest = True )
Tdulces
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                  Bocadines    Ricolino               50.0
# 3                Gelatinitas    Kellog's               40.0
# 4                 Pulparindo  De la rosa               22.0
# 5                  Skwinkles       Lucas                NaN
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               33.0
# 14               Dragoncitos      Sonrix               15.0
# 15           Paleta de mango        Vero               50.0
#
#     Unidades por paquete      Sabor Precios Estratificados
# 0                      5      Dulce                   Bajo
# 1                     80      Dulce                  Medio
# 2                     50      Dulce                   Alto
# 3                    100      Dulce                   Alto
# 4                     20  Enchiloso                   Bajo
# 5                     60  Enchiloso                    NaN
# 6                      6  Enchiloso                  Medio
# 7                      6  Enchiloso                  Medio
# 8                     40      Dulce                   Bajo
# 9                    100      Dulce                   Bajo
# 10                   100      Dulce                   Bajo
# 11                    25      Dulce                   Alto
# 12                    50      Dulce                  Medio
# 13                    12  Enchiloso                  Medio
# 14                   100      Dulce                   Bajo
# 15                    50  Enchiloso                   Alto

# %%
print(Tdulces.iloc[1:,2],len(Tdulces.iloc[:,0]))
# Out:
# 1     30.0
# 2     50.0
# 3     40.0
# 4     22.0
# 5      NaN
# 6     36.0
# 7     35.0
# 8     15.0
# 9     25.0
# 10    15.0
# 11    45.0
# 12    30.0
# 13    33.0
# 14    15.0
# 15    50.0
# Name: Costo del paquete, dtype: float64 16

# %%
Corregido = Tdulces.dropna(axis = 0)
print(Corregido)
print(type(Tdulces.loc[:,["Marca"]]))
print(type(Tdulces.loc[:,"Marca"]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
Tdulces["Costo del paquete"].replace(np.nan, Tdulces["Costo del paquete"].mean(),inplace=True)
print(Tdulces["Costo del paquete"].mean())
# Out:
# 83.4

# %%
Tdulces
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                 Pulparindo  De la rosa               35.0
# 3                 KornFalkes    Kellog's               40.0
# 4                Steel Baton        SPLM              800.0
# 5                  Skwinkles       Lucas               83.4
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               60.0
# 14               Dragoncitos      Sonrix               15.0
# 15           Paleta de mango        Vero               50.0
#
#     Unidades por paquete      Sabor
# 0                      5      Dulce
# 1                     80      Dulce
# 2                     35  Enchiloso
# 3                      1      Dulce
# 4                      1  Enchiloso
# 5                     60  Enchiloso
# 6                      6  Enchiloso
# 7                      6  Enchiloso
# 8                     40      Dulce
# 9                    100      Dulce
# 10                   100      Dulce
# 11                    25      Dulce
# 12                    50      Dulce
# 13                    25  Enchiloso
# 14                   100      Dulce
# 15                    50  Enchiloso

# %%
pd.get_dummies(Tdulces["Sabor"])
# Out:
#     Dulce  Enchiloso
# 0       1          0
# 1       1          0
# 2       0          1
# 3       1          0
# 4       0          1
# 5       0          1
# 6       0          1
# 7       0          1
# 8       1          0
# 9       1          0
# 10      1          0
# 11      1          0
# 12      1          0
# 13      0          1
# 14      1          0
# 15      0          1

# %%
Tdulces["Sabor"] = pd.get_dummies(Tdulces["Sabor"])
Tdulces
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                 Pulparindo  De la rosa               35.0
# 3                 KornFalkes    Kellog's               40.0
# 4                Steel Baton        SPLM              800.0
# 5                  Skwinkles       Lucas               83.4
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               60.0
# 14               Dragoncitos      Sonrix               15.0
# 15           Paleta de mango        Vero               50.0
#
#     Unidades por paquete  Sabor
# 0                      5      1
# 1                     80      1
# 2                     35      0
# 3                      1      1
# 4                      1      0
# 5                     60      0
# 6                      6      0
# 7                      6      0
# 8                     40      1
# 9                    100      1
# 10                   100      1
# 11                    25      1
# 12                    50      1
# 13                    25      0
# 14                   100      1
# 15                    50      0
