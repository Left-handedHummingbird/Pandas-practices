# %%
import pandas as pd
import numpy as np

Tdulces = pd.read_excel("C:\\Users\\Nobody\\Documents\\Python Scripts\\File.xlsx")

# %%
Precios = Tdulces[['Costo del paquete']]

# %%
Estratos = np.linspace(Precios.min(),Precios.max(),4)

# %%
Cabeceras = ["Bajo","Medio","Alto"]

# %%
Tdulces['Precios Estratificados'] = pd.cut(Tdulces ["Costo del paquete"] ,Estratos, right = False, labels=Cabeceras)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2e6a3ac493c7> in <module>
# ----> 1 Tdulces['Precios Estratificados'] = pd.cut(Tdulces ["Costo del paquete"] ,Estratos, right = False, labels=Cabeceras)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     239                               include_lowest=include_lowest,
#     240                               dtype=dtype,
# --> 241                               duplicates=duplicates)
#     242
#     243     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     332         return result, bins
#     333
# --> 334     unique_bins = algos.unique(bins)
# ...

# %%
#this is a weird error

# %%
print(Tdulces)
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                 Pulparindo  De la rosa               35.0
# 3                 KornFalkes    Kellog's               40.0
# 4                Steel Baton        SPLM              800.0
# 5                  Skwinkles       Lucas                NaN
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               60.0
# 14               Dragoncitos      Sonrix               15.0
# ...

# %%
Corregido = Tdulces.dropna(axis = 0)
print(Corregido)
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                 Pulparindo  De la rosa               35.0
# 3                 KornFalkes    Kellog's               40.0
# 4                Steel Baton        SPLM              800.0
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               60.0
# 14               Dragoncitos      Sonrix               15.0
# 15           Paleta de mango        Vero               50.0
#
# ...

# %%
Tdulces["Costo del paquete"].replace(np.nan, Tdulces["Costo del paquete"].mean(),inplace=True)
print(Tdulces["Costo del paquete"].mean())
# Out:
# 83.4

# %%
Tdulces
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                 Pulparindo  De la rosa               35.0
# 3                 KornFalkes    Kellog's               40.0
# 4                Steel Baton        SPLM              800.0
# 5                  Skwinkles       Lucas               83.4
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               60.0
# 14               Dragoncitos      Sonrix               15.0
# ...

# %%
pd.get_dummies(Tdulces["Sabor"])
# Out:
#     Dulce  Enchiloso
# 0       1          0
# 1       1          0
# 2       0          1
# 3       1          0
# 4       0          1
# 5       0          1
# 6       0          1
# 7       0          1
# 8       1          0
# 9       1          0
# 10      1          0
# 11      1          0
# 12      1          0
# 13      0          1
# 14      1          0
# 15      0          1

# %%
Tdulces["Sabor"] = pd.get_dummies(Tdulces["Sabor"])
Tdulces
# Out:
#                     Producto       Marca  Costo del paquete  \
# 0                    Mazapan  De la rosa               20.0
# 1           Paleta de cereza  De la rosa               30.0
# 2                 Pulparindo  De la rosa               35.0
# 3                 KornFalkes    Kellog's               40.0
# 4                Steel Baton        SPLM              800.0
# 5                  Skwinkles       Lucas               83.4
# 6            Pelón pelo rico       Lucas               36.0
# 7               Lucas muecas       Lucas               35.0
# 8   Paletas de caramelo duro      Sonrix               15.0
# 9                     Chicle  De la rosa               25.0
# 10                    Velita      Sonrix               15.0
# 11                  Bubulubu    Ricolino               45.0
# 12           Gomita malvabon    Ricolino               30.0
# 13    Cacahuate japonés 450g  De la rosa               60.0
# 14               Dragoncitos      Sonrix               15.0
# ...
